# %%
from __future__ import absolute_import, division, print_function

# %%
# License: MIT

# %%
# %matplotlib inline

# %% [markdown]
# ## Packages

# %%
import numpy as np
import scipy as scipy
import scipy.stats as stats
import scipy.linalg as linalg
from pprint import pprint

import matplotlib.gridspec as gridspec
import matplotlib.path as mpath
import matplotlib.pyplot as plt

import sys
import os
import copy
import string
import glob
import xarray as xr 

import warnings

# %% [markdown]
# # Define Map

# %%
def f(x,lam): 
    fout = (1+lam)*x - x**2;
    return fout

# %% [markdown]
# # Period 2 solution
# ## Set parameters

# %%
lam = 2.1;
Nsteps = 1000;
x0 = np.array([0.5]);

# %% [markdown]
# ## Create empty solution vector

# %%
xtraj = np.empty((Nsteps+1,1));
xtraj[:] = np.nan

# input initial condition
xtraj[0,:] = x0;

# %% [markdown]
# ## Iterate map

# %%
for i in np.arange(0,Nsteps):
    x0 = f(x0,lam);
    xtraj[i+1,:] = x0;

# %% [markdown]
# ## Plot solution

# %%
fig, axs = plt.subplots(1, 2, layout='constrained', figsize=(10, 5))

ax1 = axs[0]
ax1.plot(xtraj[100:-1,:],xtraj[101:,:],'.')
ax1.set_xlabel("$x_n$")
ax1.set_ylabel("$x_{n+1}$")
ax1.set_title("Solution Trajectory in Phase Plane")
ax1.set_xlim([-np.abs(lam)-1, np.abs(lam)+1])
ax1.set_ylim([-np.abs(lam)-1, np.abs(lam)+1])

ax2 = axs[1] 
ax2.plot(np.arange(0,Nsteps+1),xtraj,'.')
ax2.set_xlabel("$n$")
ax2.set_ylabel("$x_n$")
ax2.set_title("Solution Trajectory")
ax2.set_xlim([0, 1000])

plt.show()

# %% [markdown]
# # Period 4 solution
# ## Set parameters

# %%
lam = 2.52;
Nsteps = 1000;
x0 = np.array([0.5]);

# %% [markdown]
# ## Create empty solution vector

# %%
xtraj = np.empty((Nsteps+1,1));
xtraj[:] = np.nan

# input initial condition
xtraj[0,:] = x0;

# %% [markdown]
# ## Iterate map

# %%
for i in np.arange(0,Nsteps):
    x0 = f(x0,lam);
    xtraj[i+1,:] = x0;

# %% [markdown]
# ## Plot solution

# %%
fig, axs = plt.subplots(1, 2, layout='constrained', figsize=(10, 5))

ax1 = axs[0]
ax1.plot(xtraj[100:-1,:],xtraj[101:,:],'.')
ax1.set_xlabel("$x_n$")
ax1.set_ylabel("$x_{n+1}$")
ax1.set_title("Solution Trajectory in Phase Plane")
ax1.set_xlim([-np.abs(lam)-1, np.abs(lam)+1])
ax1.set_ylim([-np.abs(lam)-1, np.abs(lam)+1])

ax2 = axs[1] 
ax2.plot(np.arange(0,Nsteps+1),xtraj,'.')
ax2.set_xlabel("$n$")
ax2.set_ylabel("$x_n$")
ax2.set_title("Solution Trajectory")
ax2.set_xlim([0, 1000])

plt.show()

# %% [markdown]
# # Period 8 solution
# ## Set parameters

# %%
lam = 2.56;
Nsteps = 1000;
x0 = np.array([0.5]);

# %% [markdown]
# ## Create empty solution vector

# %%
xtraj = np.empty((Nsteps+1,1));
xtraj[:] = np.nan

# input initial condition
xtraj[0,:] = x0;

# %% [markdown]
# ## Iterate map

# %%
for i in np.arange(0,Nsteps):
    x0 = f(x0,lam);
    xtraj[i+1,:] = x0;

# %% [markdown]
# ## Plot solution

# %%
fig, axs = plt.subplots(1, 2, layout='constrained', figsize=(10, 5))

ax1 = axs[0]
ax1.plot(xtraj[100:-1,:],xtraj[101:,:],'.')
ax1.set_xlabel("$x_n$")
ax1.set_ylabel("$x_{n+1}$")
ax1.set_title("Solution Trajectory in Phase Plane")
ax1.set_xlim([-np.abs(lam)-1, np.abs(lam)+1])
ax1.set_ylim([-np.abs(lam)-1, np.abs(lam)+1])

ax2 = axs[1] 
ax2.plot(np.arange(0,Nsteps+1),xtraj,'.')
ax2.set_xlabel("$n$")
ax2.set_ylabel("$x_n$")
ax2.set_title("Solution Trajectory")
ax2.set_xlim([0, 1000])

plt.show()

# %% [markdown]
# # Chaos
# ## Set parameters

# %%
lam = 2.7;
Nsteps = 1000;
x0 = np.array([0.5]);

# %% [markdown]
# ## Create empty solution vector

# %%
xtraj = np.empty((Nsteps+1,1));
xtraj[:] = np.nan

# input initial condition
xtraj[0,:] = x0;

# %% [markdown]
# ## Iterate map

# %%
for i in np.arange(0,Nsteps):
    x0 = f(x0,lam);
    xtraj[i+1,:] = x0;

# %% [markdown]
# ## Plot solution

# %%
fig, axs = plt.subplots(1, 2, layout='constrained', figsize=(10, 5))

ax1 = axs[0]
ax1.plot(xtraj[100:-1,:],xtraj[101:,:],'.')
ax1.set_xlabel("$x_n$")
ax1.set_ylabel("$x_{n+1}$")
ax1.set_title("Solution Trajectory in Phase Plane")
ax1.set_xlim([-np.abs(lam)-1, np.abs(lam)+1])
ax1.set_ylim([-np.abs(lam)-1, np.abs(lam)+1])

ax2 = axs[1] 
ax2.plot(np.arange(0,Nsteps+1),xtraj,'.')
ax2.set_xlabel("$n$")
ax2.set_ylabel("$x_n$")
ax2.set_title("Solution Trajectory")
ax2.set_xlim([0, 1000])

plt.show()
